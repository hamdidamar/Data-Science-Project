# %% [markdown]
# This Data Analysis for Fifa 2019.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fifa = pd.read_csv('fifa_19.csv')

# %%
fifa.head(5)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
fifa.tail(5)
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 18202  https://cdn.sofifa.org/players/4/19/238813.png     England
# 18203  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 18204  https://cdn.sofifa.org/players/4/19/241638.png     England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 18202  https://cdn.sofifa.org/flags/14.png       47         65
# 18203  https://cdn.sofifa.org/flags/46.png       47         63
# 18204  https://cdn.sofifa.org/flags/14.png       47         67
# ...

# %%
fifa.Finishing.plot(kind = 'line', color = 'g',label = 'Finishing',linewidth=1,alpha = 0.5,grid = True,linestyle = ':')
fifa.Positioning.plot(color = 'r',label = 'Positioning',linewidth=1, alpha = 0.5,grid = True,linestyle = '-.')
plt.legend(loc='upper right') 
plt.xlabel('x axis') 
plt.ylabel('y axis')
plt.title('Line Plot') 
plt.show()

# %%
fifa.SprintSpeed.plot(kind = 'hist',bins = 50,figsize = (12,12))
plt.show()

# %%
dataV1 = fifa.loc[:,["Age","Potential","Overall"]]
dataV1.plot()

# %%
data1.plot(subplots = True)
plt.show()

# %%
data1 = fifa.set_index(["Name","Club","Value"]) 
data1.head(100)
# Out:
#                                                             Unnamed: 0  \
# Name                Club                           Value
# L. Messi            FC Barcelona                   €110.5M           0
# Cristiano Ronaldo   Juventus                       €77M              1
# Neymar Jr           Paris Saint-Germain            €118.5M           2
# De Gea              Manchester United              €72M              3
# K. De Bruyne        Manchester City                €102M             4
# E. Hazard           Chelsea                        €93M              5
# L. Modrić           Real Madrid                    €67M              6
# L. Suárez           FC Barcelona                   €80M              7
# Sergio Ramos        Real Madrid                    €51M              8
# J. Oblak            Atlético Madrid                €68M              9
# R. Lewandowski      FC Bayern München              €77M             10
# ...

# %%
df = pd.DataFrame(fifa)
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
# Unnamed: 0                  18207 non-null int64
# ID                          18207 non-null int64
# Name                        18207 non-null object
# Age                         18207 non-null int64
# Photo                       18207 non-null object
# Nationality                 18207 non-null object
# Flag                        18207 non-null object
# Overall                     18207 non-null int64
# Potential                   18207 non-null int64
# Club                        17966 non-null object
# Club Logo                   18207 non-null object
# Value                       18207 non-null object
# Wage                        18207 non-null object
# Special                     18207 non-null int64
# Preferred Foot              18159 non-null object
# International Reputation    18159 non-null float64
# Weak Foot                   18159 non-null float64
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
df.shape
# Out:
# (18207, 89)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                      0
# ID                              0
# Name                            0
# Age                             0
# Photo                           0
# Nationality                     0
# Flag                            0
# Overall                         0
# Potential                       0
# Club                          241
# Club Logo                       0
# Value                           0
# Wage                            0
# Special                         0
# Preferred Foot                 48
# International Reputation       48
# Weak Foot                      48
# Skill Moves                    48
# Work Rate                      48
# Body Type                      48
# Real Face                      48
# Position                       60
# Jersey Number                  60
# Joined                       1553
# Loaned From                 16943
# Contract Valid Until          289
# Height                         48
# ...

# %%
chosen_columns = ['Name','Age','Nationality','Overall','Potential','Special','Acceleration','Aggression','Agility','Balance',
'BallControl','Body Type','Composure','Crossing','Curve','Club','Dribbling','FKAccuracy','Finishing','GKDiving','GKHandling','GKKicking',
'GKPositioning','GKReflexes','HeadingAccuracy','Interceptions','International Reputation','Jersey Number','Jumping','Joined','LongPassing',
'LongShots','Marking','Penalties','Position','Positioning','Preferred Foot','Reactions','ShortPassing','ShotPower','Skill Moves','SlidingTackle',
'SprintSpeed','Stamina','StandingTackle','Strength','Value','Vision','Volleys','Wage','Weak Foot','Work Rate'
]

# %%
df = pd.DataFrame(df, columns = chosen_columns)
df.head()
# Out:
#                    Name  Age Nationality  Overall  Potential  Special  \
# Name
# L. Messi            NaN   31   Argentina       94         94     2202
# Cristiano Ronaldo   NaN   33    Portugal       94         94     2228
# Neymar Jr           NaN   26      Brazil       92         93     2143
# De Gea              NaN   27       Spain       91         93     1471
# K. De Bruyne        NaN   27     Belgium       91         92     2281
#
#                    Acceleration  Aggression  Agility  Balance       ...        \
# Name                                                                ...
# L. Messi                   91.0        48.0     91.0     95.0       ...
# Cristiano Ronaldo          89.0        63.0     87.0     70.0       ...
# Neymar Jr                  94.0        56.0     96.0     84.0       ...
# De Gea                     57.0        38.0     60.0     43.0       ...
# K. De Bruyne               78.0        76.0     79.0     77.0       ...
#
# ...

# %%
df.sample(5)
# Out:
#                  Name  Age       Nationality  Overall  Potential  Special  \
# 3417  Ricardo Valente   27          Portugal       72         72     1751
# 887           J. Lens   30       Netherlands       78         78     1988
# 4731   Cristian López   29             Spain       71         71     1703
# 5423        P. McNair   23  Northern Ireland       70         78     1803
# 853        O. Özyakup   25            Turkey       78         81     2105
#
#       Acceleration  Aggression  Agility  Balance       ...        SprintSpeed  \
# 3417          74.0        74.0     71.0     65.0       ...               73.0
# 887           90.0        53.0     75.0     79.0       ...               90.0
# 4731          79.0        79.0     68.0     58.0       ...               74.0
# 5423          63.0        76.0     58.0     63.0       ...               64.0
# 853           71.0        75.0     88.0     79.0       ...               72.0
#
# ...

# %%
df.set_index('Name', inplace=True)

# %%
df.describe()
# Out:
#                 Age       Overall     Potential       Special  Acceleration  \
# count  18207.000000  18207.000000  18207.000000  18207.000000  18159.000000
# mean      25.122206     66.238699     71.307299   1597.809908     64.614076
# std        4.669943      6.908930      6.136496    272.586016     14.927780
# min       16.000000     46.000000     48.000000    731.000000     12.000000
# 25%       21.000000     62.000000     67.000000   1457.000000     57.000000
# 50%       25.000000     66.000000     71.000000   1635.000000     67.000000
# 75%       28.000000     71.000000     75.000000   1787.000000     75.000000
# max       45.000000     94.000000     95.000000   2346.000000     97.000000
#
#          Aggression       Agility       Balance   BallControl     Composure  \
# count  18159.000000  18159.000000  18159.000000  18159.000000  18159.000000
# mean      55.868991     63.503607     63.966573     58.369459     58.648274
# ...

# %%
df['Nationality'].value_counts().head()
# Out:
# England      1662
# Germany      1198
# Spain        1072
# Argentina     937
# France        914
# Name: Nationality, dtype: int64

# %%
df['Nationality'].value_counts().tail()
# Out:
# Botswana       1
# Jordan         1
# South Sudan    1
# Lebanon        1
# Oman           1
# Name: Nationality, dtype: int64

# %%
df['Club'].value_counts().head(10)
# Out:
# Cardiff City           33
# Newcastle United       33
# Rayo Vallecano         33
# Everton                33
# Southampton            33
# Valencia CF            33
# RC Celta               33
# Tottenham Hotspur      33
# TSG 1899 Hoffenheim    33
# Frosinone              33
# Name: Club, dtype: int64

# %%
en_genc = df.sort_values('Age', ascending = True)[[ 'Age', 'Club', 'Nationality']].head(10)

# %%
en_yasli = df.sort_values('Age', ascending = False)[['Age', 'Club', 'Nationality']].head(10)

# %%
en_genc
# Out:
#                 Age             Club          Nationality
# Name
# G. Nugent        16  Tranmere Rovers              England
# J. Olstad        16  Sarpsborg 08 FF               Norway
# H. Massengo      16        AS Monaco               France
# J. Italiano      16      Perth Glory            Australia
# N. Ayéva         16        Örebro SK               Sweden
# K. Broda         16     Wisła Kraków               Poland
# L. D'Arrigo      16  Adelaide United            Australia
# Y. Verschaeren   16   RSC Anderlecht              Belgium
# B. Nygren        16     IFK Göteborg               Sweden
# B. O'Gorman      16   Bray Wanderers  Republic of Ireland

# %%
en_yasli
# Out:
#                Age                          Club        Nationality
# Name
# O. Pérez        45                       Pachuca             Mexico
# K. Pilkington   44              Cambridge United            England
# T. Warner       44            Accrington Stanley  Trinidad & Tobago
# S. Narazaki     42                Nagoya Grampus              Japan
# C. Muñoz        41  CD Universidad de Concepción          Argentina
# J. Villar       41                           NaN           Paraguay
# H. Sulaimani    41                     Ohod Club       Saudi Arabia
# M. Tyler        41           Peterborough United            England
# B. Nivet        41                  ESTAC Troyes             France
# F. Kippe        40                 Lillestrøm SK             Norway

# %%
sns.set(style="darkgrid") 
ax = sns.countplot(x = 'Position' ,data = df) 
ax.set_title(label='Pozisyondaki Oyuncu Sayısı', fontsize=30);
plt.show()

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000249163F04E0>,
# ...
#       dtype=object)

# %%
df.corr()
# Out:
#                           Unnamed: 0        ID       Age   Overall  Potential  \
# Unnamed: 0                  1.000000  0.415757 -0.454846 -0.972791  -0.633395
# ID                          0.415757  1.000000 -0.739208 -0.417025   0.047074
# Age                        -0.454846 -0.739208  1.000000  0.452350  -0.253312
# Overall                    -0.972791 -0.417025  0.452350  1.000000   0.660939
# Potential                  -0.633395  0.047074 -0.253312  0.660939   1.000000
# Special                    -0.596508 -0.231352  0.236695  0.606960   0.383727
# International Reputation   -0.413322 -0.356191  0.253765  0.499491   0.372993
# Weak Foot                  -0.204026 -0.075784  0.059867  0.212015   0.162346
# Skill Moves                -0.415672 -0.056914  0.027649  0.414463   0.354290
# Jersey Number               0.213645  0.182074 -0.241156 -0.218931  -0.010474
# Crossing                   -0.390062 -0.131994  0.130545  0.394972   0.246319
# ...

# %%
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...
